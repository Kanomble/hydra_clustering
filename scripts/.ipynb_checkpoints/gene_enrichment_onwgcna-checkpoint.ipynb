# %%
import pandas as pd

# %%
popfile = "../data/goatools_data/population.txt"
population_genes = []
with open(popfile,"r") as pfile:
    for line in pfile.readlines():
        population_genes.append(line.rstrip())

# %%
df = pd.read_csv("../results/deseq2_rsem_sortmerna/tables/EcoKD1_Eco1KD_B8_vs_control_B8_results.csv")
df["gene"] = df["Unnamed: 0"].apply(lambda x: x.split(".")[1])
df.head()
# Out:
#        Unnamed: 0      baseMean  log2FoldChange     lfcSE       stat  \
# 0  HVAEP6.G011796  12798.527212       -8.360376  0.142271 -58.763709
# 1  HVAEP2.G004481    593.302203       -2.924442  0.120817 -24.205573
# 2  HVAEP1.G000426   4327.267824        3.236053  0.133985  24.152419
# 3  HVAEP2.G004333   1218.077185       -2.766741  0.116381 -23.773192
# 4  HVAEP1.G000462    221.133476        3.253983  0.146209  22.255764
#
#           pvalue           padj     gene
# 0   0.000000e+00   0.000000e+00  G011796
# 1  1.943572e-129  1.570212e-125  G004481
# 2  7.042132e-129  3.792892e-125  G000426
# 3  6.326138e-125  2.555443e-121  G004333
# 4  9.918827e-110  3.205368e-106  G000462

# %%
sample = "../results/network_analysis/genes_module_yellow.txt"
samplefile = "../results/network_analysis/goatools_ecokd1_sample_genes.txt"
sample_genes = []
with open(sample,"r") as sfile:
    with open(samplefile,"w") as sgenes:
        for line in sfile.readlines():
            gene = line.split(".")[1]
            gene = gene.rstrip()
            if gene in population_genes:
                if gene in df["gene"].to_list():
                    # print(gene)
                    sample_genes.append(gene)
                    sgenes.write(gene+"\n")
# Out:
# G014330
# G027266
# G020672
# G014397
# G020533
# G014585
# G012242
# G010037
# G022878
# G002696
# G015093
# G017487
# G013599
# G024954
# G010751
# G014396
# G003762
# G012585
# G012053
# G014365
# G002480
# G023536
# G017962
# G022973

# %%
outfile = "../results/network_analysis/enrichment_ecokd1_sample_genes.txt"

# %%
# !find_enrichment.py $samplefile ../data/goatools_data/population.txt ../data/goatools_data/associations.txt --annofmt id2gos --alpha 0.05 --pval 0.05 --obo ../data/goatools_data/go-basic.obo --method fdr_bh --outfile $outfile --obsolete replace > /dev/null
