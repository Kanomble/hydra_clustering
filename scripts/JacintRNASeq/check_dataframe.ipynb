# %%
import pandas as pd

# %%
pd.read_csv("../../results/jacint_results/reg_rnaseq/orthofinder_ogs_deseq/DESeq2_T0_AS_vs_S_MergedOGs.csv")
# Out:
#            Unnamed: 0     baseMean  log2FoldChange     lfcSE    pvalue  \
# 0      HVAEP6.G011316  1551.088384        0.270982  0.139795  0.052571
# 1      HVAEP6.G011316  1551.088384        0.270982  0.139795  0.052571
# 2      HVAEP6.G011470   306.830383        0.326936  0.189953  0.085225
# 3      HVAEP6.G011470   306.830383        0.326936  0.189953  0.085225
# 4      HVAEP6.G011470   306.830383        0.326936  0.189953  0.085225
# ...               ...          ...             ...       ...       ...
# 96755  HVAEP1.G002153   492.615762        0.983745  0.379239  0.009487
# 96756  HVAEP1.G002176   492.615762        0.983745  0.379239  0.009487
# 96757  HVAEP1.G002177   492.615762        0.983745  0.379239  0.009487
# 96758  HVAEP1.G002178   492.615762        0.983745  0.379239  0.009487
# 96759  HVAEP1.G002179   492.615762        0.983745  0.379239  0.009487
#
#            padj
# 0      0.236708
# 1      0.236708
# 2      0.321666
# 3      0.321666
# 4      0.321666
# ...

# %%
pd.read_table("../../results/deseq2_rsem_final/hydra_all_deseq2_lg2.tsv")
# Out:
#                     ID  EcoKD1_Eco1KD_B8_vs_control_B8  \
# 0       HVAEP6.G011796                       -8.360376
# 1       HVAEP2.G004481                       -2.924442
# 2       HVAEP1.G000426                        3.236053
# 3       HVAEP2.G004333                       -2.766741
# 4       HVAEP1.G000462                        3.253983
# ...                ...                             ...
# 19424   HVAEP4.G007784                             NaN
# 19425  HVAEP10.G018079                             NaN
# 19426  HVAEP13.G024559                             NaN
# 19427   HVAEP3.G005290                             NaN
# 19428   HVAEP5.G010066                             NaN
#
#        HydraAHL_3OC12_vs_control  HydraAHL_3OHC12_vs_control  \
# 0                       0.726897                    0.932251
# 1                       0.008712                    0.033244
# 2                      -0.683156                   -0.433207
# ...
