# %%
with open("../../data/jacint_data/REG_RNASeq/reg2_cdhit.Trinity.fasta.transdecoder.pep","r") as infile:
    with open("../../data/jacint_data/REG_RNASeq/holi_protein_regeneration.fa","w") as outfile:
        for line in infile.readlines():
            if line.startswith(">"):
                line = line.split(" ")[0]
            line = line.strip()
            line = line + "\n"
            outfile.write(line)
