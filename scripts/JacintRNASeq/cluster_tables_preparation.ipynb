# %%
import pandas as pd

# %% [markdown]
# # Change deseq2 table header

# %%
df = pd.read_csv("../../results/jacint_results/reg_rnaseq/hydra_all_deseq2_lg2.tsv", sep="\t")
df.ID = df.ID.apply(lambda x: "HVAEP1-" + x.split(".")[1])
df.to_csv("../../results/jacint_results/reg_rnaseq/hydra_all_deseq2_lg2_t_to_g.tsv", sep="\t", header=True, index=False)

df = pd.read_csv("../../results/jacint_results/reg_rnaseq/hydra_all_deseq2_pvalues.tsv", sep="\t")
df.ID = df.ID.apply(lambda x: "HVAEP1-" + x.split(".")[1])
df.to_csv("../../results/jacint_results/reg_rnaseq/hydra_all_deseq2_pvalues_t_to_g.tsv", sep="\t", header=True, index=False)
df.head()
# Out:
#                ID  DESeq2_T0_AS_vs_S  DESeq2_T1_AS_vs_S  DESeq2_T2_AS_vs_S  \
# 0  HVAEP1-G011316           0.236708           0.112168       6.400729e-02
# 1  HVAEP1-G011470           0.321666           0.441618       4.988170e-04
# 2  HVAEP1-G014841           0.198724           0.000002       1.141106e-13
# 3  HVAEP1-G014844           0.198724           0.000002       1.141106e-13
# 4  HVAEP1-G000137           0.343736           0.868630       6.483038e-01
#
#    DESeq2_T3_AS_vs_S
# 0           0.097265
# 1           0.095035
# 2           0.002835
# 3           0.002835
# 4           0.904801
